# %%
import matplotlib.pyplot as plt
import numpy as np

from trendfilterpy._estimator import TrendFilterRegression

rng = np.random.default_rng()

# %%
Ns = rng.integers(100, 500, 1000)

# %%
Ns
# Out:
# array([418, 151, 214, 351, 260, 221, 134, 155, 479, 455, 129, 217, 173,
#        324, 267, 136, 422, 469, 386, 393, 102, 227, 132, 370, 180, 341,
#        197, 345, 425, 121, 275, 460, 373, 212, 302, 330, 465, 391, 200,
#        249, 433, 280, 369, 223, 480, 175, 232, 465, 150, 250, 322, 188,
#        321, 325, 263, 257, 165, 455, 224, 258, 241, 321, 481, 358, 456,
#        413, 217, 306, 463, 420, 142, 470, 259, 116, 140, 463, 407, 117,
#        203, 118, 186, 130, 221, 110, 215, 290, 206, 149, 401, 165, 212,
#        401, 251, 385, 231, 176, 475, 327, 229, 230, 484, 262, 362, 398,
#        381, 285, 253, 491, 280, 471, 486, 455, 454, 354, 115, 152, 164,
#        460, 224, 221, 146, 391, 126, 204, 144, 428, 332, 418, 248, 347,
#        150, 488, 271, 111, 404, 440, 162, 190, 417, 226, 283, 349, 420,
#        466, 381, 152, 427, 274, 230, 418, 364, 406, 374, 433, 306, 127,
#        299, 131, 341, 364, 270, 333, 446, 498, 137, 478, 283, 287, 161,
# ...
